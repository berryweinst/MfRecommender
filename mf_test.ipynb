# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from scipy.sparse.linalg import spsolve
from scipy import sparse
from data import *




class MFModel(object):

    def __init__(self, rates_dict, test_rates_dict, num_users, num_items, 
                 hidden_dim, lr, gamma, epochs, optimizer, reg_u, reg_i, confidence=1):
        """ Params:
        1) ratings - rating matrix (as dict)
        2) hidden_dim  - number of latent dimensions (as integer)
        3) lr - learning rate (as float)
        4) gamma - regulaizer (as float)
        5) opechs - as int
        """

        self.ratings_dict = rates_dict
        self.test_ratings_dict = test_rates_dict
        self.num_users = num_users
        self.num_items = num_items
        self.K = hidden_dim
        self.optimizer = optimizer
        self.lr = lr
        self.gamma = gamma
        self.regulizer_items = reg_i
        self.regulizer_users = reg_u
        self.confidence = confidence
        self.epochs = epochs
        self.scbd = []
        
    def print_hyper_params(self):
        print("latent dimention %d" % (self.K))
        print("learning rate %r" % (self.lr))
        print("lambda SGD %r" % (self.gamma))
        print("lambda ALS users %r" % (self.regulizer_users))
        print("lambda ALS items %r" % (self.regulizer_items))
        print("Confidence ALS %d" % (self.confidence))
        print("Epochs %d" % (self.epochs))

    def init(self, isize, ik, kind='normal'):
        if kind == 'normal':
            return np.random.normal(scale=1.0/ik, size=(isize, ik))
        elif kind == 'uniform':
            return np.random.uniform(-1.0/ik, 1.0/ik)


    def train_model(self):

        def reset(samples):
            np.random.shuffle(samples)

        self.samples = []
        # prepare the samples samples
        for u, items in self.ratings_dict.items():
            for i, r, _ in items:
                self.samples += [(u, i, r)]

        self.U = self.init(self.num_users, self.K, kind='normal')
        self.V = self.init(self.num_items, self.K, kind='normal')
        
        #sparse intermidiate representation
        self.Us = sparse.csr_matrix(self.U)
        self.Vs = sparse.csr_matrix(self.V)

        # Initialize the biases
        self.bu = np.zeros(self.num_users)
        self.bv = np.zeros(self.num_items)


        for epoch in range(self.epochs):
            reset(self.samples)
            if self.optimizer == 'sgd':
                self.LearnModelFromDataUsingSGD()
            elif self.optimizer == 'als':
                self.LearnModelFromDataUsingALS()
            train_rmse = self.RMSE(is_train=True)
            val_rmse = self.RMSE()
            print("[Epoch %d] : train RMSE = %.4f" % (epoch, train_rmse))
            if epoch % 5 == 0:
                print("[Epoch %d] : validation RMSE = %.4f" % (epoch, val_rmse))
            self.scbd.append((epoch, train_rmse, val_rmse))


    def LearnModelFromDataUsingSGD (self):
        """
        Performs one iteration on one of the User/Items matrices
        """    
        for u, v, rate in self.samples:
            prediction = self.bu[u] + self.bv[v] + self.U[u, :].dot(self.V[v, :].T)
            err = (rate - prediction)

            # update biases
            self.bu[u] += self.lr * (err - self.gamma * self.bu[u])
            self.bv[v] += self.lr * (err - self.gamma * self.bv[v])

            # update user item metrices
            self.U[u, :] += self.lr * (err * self.V[v, :] - self.gamma * self.U[u, :])
            self.V[v, :] += self.lr * (err * self.U[u, :] - self.gamma * self.V[v, :])
            
    
    def LearnModelFromDataUsingALS(self):
        """
        Performs one iteration on one of the User/Items matrices
        """
        rate_mat = np.zeros((self.num_users, self.num_items))
        for user, item in self.ratings_dict.items():
            for movie, rate, _ in item:
                rate_mat[user][movie] = rate
        rate_mat = sparse.csr_matrix(rate_mat) * self.confidence

        U_i = sparse.eye(self.num_users)
        V_i = sparse.eye(self.num_items)

        # UtU = self.Us.T.dot(self.Us)
        # VtV = self.Vs.T.dot(self.Vs)

        # Users update
        lambda_u = sparse.eye(self.K) * self.regulizer_users
        for u_idx, u_rate in enumerate(rate_mat):
            u_dense = u_rate.toarray()
            u_bin = u_dense.copy()
            u_bin[u_bin != 0] = 1.0
            u_diag = sparse.diags(u_dense, [0])
            VtV = self.Vs.T.dot(u_diag).dot(self.Vs)
            VtV_u = self.Vs.T.dot(u_diag).dot(u_dense.T)
            self.Us[u_idx, :] = spsolve(VtV + lambda_u, VtV_u)



        # Items update
        lambda_i = sparse.eye(self.K) * self.regulizer_items
        for i_idx, i_rate in enumerate(rate_mat.T):
            i_dense = i_rate.toarray()
            i_bin = i_dense.copy()
            i_bin[i_bin != 0] = 1.0
            i_diag = sparse.diags(i_dense, [0])
            UtU = self.Us.T.dot(i_diag).dot(self.Us)
            UtU_i = self.Us.T.dot(i_diag).dot(i_dense.T)
            self.Vs[i_idx, :] = spsolve(UtU + lambda_i, UtU_i)

        self.U = self.Us.toarray()
        self.V = self.Vs.toarray()



            
    def RMSE(self, is_train=False):
        mod_pred = self.bu[:,np.newaxis] + self.bv[np.newaxis:,] + self.U.dot(self.V.T)
        total_err = 0
        r_cnt = 0
        ratings_dict = self.ratings_dict if is_train else self.test_ratings_dict
        for u, items in ratings_dict.items():
            for i, r, _ in items:
                total_err += pow(r - mod_pred[u, i], 2)
                r_cnt += 1
        return np.sqrt(total_err / r_cnt)

# Load the data
X_train, X_test, users, items = create_user_item_map('../ml-1m/ratings.dat', '', percent=0.8, sort_ratings=True)

# %%
# 1a - SGD
model = MFModel(X_train, X_test, users, items, hidden_dim=40, lr=0.01, gamma=0.1, reg_u=0.1, reg_i=0.1, epochs=22, optimizer='sgd')
print("Starting training SGD...")
model.print_hyper_params()
model.train_model()
# Out:
# Starting training SGD...
# latent dimention 40
# learning rate 0.01
# lambda SGD 0.1
# lambda ALS users 0.1
# lambda ALS items 0.1
# Epochs 22
# [Epoch 0] : train RMSE = 1.0481
# [Epoch 0] : validation RMSE = 1.0967
# [Epoch 1] : train RMSE = 0.9747
# [Epoch 2] : train RMSE = 0.9505
# [Epoch 3] : train RMSE = 0.9372
# [Epoch 4] : train RMSE = 0.9301
# [Epoch 5] : train RMSE = 0.9250
# [Epoch 5] : validation RMSE = 0.9443
# [Epoch 6] : train RMSE = 0.9184
# [Epoch 7] : train RMSE = 0.9107
# [Epoch 8] : train RMSE = 0.9026
# [Epoch 9] : train RMSE = 0.8951
# [Epoch 10] : train RMSE = 0.8885
# [Epoch 10] : validation RMSE = 0.9132
# [Epoch 11] : train RMSE = 0.8831
# [Epoch 12] : train RMSE = 0.8783
# [Epoch 13] : train RMSE = 0.8730
# [Epoch 14] : train RMSE = 0.8686
# [Epoch 15] : train RMSE = 0.8660
# [Epoch 15] : validation RMSE = 0.8979
# [Epoch 16] : train RMSE = 0.8630
# [Epoch 17] : train RMSE = 0.8607
# [Epoch 18] : train RMSE = 0.8581
# [Epoch 19] : train RMSE = 0.8560
# [Epoch 20] : train RMSE = 0.8543
# [Epoch 20] : validation RMSE = 0.8906
# [Epoch 21] : train RMSE = 0.8527

# %%
train_rmse = [t for e, t, v in model.scbd]
test_rmse = [v for e, t, v in model.scbd]
epochs = [e for e, t, v in model.scbd]
plt.figure(figsize=((16,4)))
plt.plot(epochs, train_rmse, label="Train")
plt.plot(epochs, test_rmse, label="Test")
plt.legend()
plt.xticks(epochs, fontsize=8)
plt.xlabel("Epochs")
plt.ylabel("RMSE")
plt.grid(axis="y")

# %%
# 1b - ALS
model = MFModel(X_train, X_test, users, items, hidden_dim=15, lr=0.001, gamma=0.1, reg_u=0.1, reg_i=0.1, epochs=21, optimizer='als')
print("Starting training ALS...")
model.print_hyper_params()
model.train_model()
# Out:
# Starting training ALS...
# latent dimention 15
# learning rate 0.001
# lambda SGD 0.1
# lambda ALS users 0.1
# lambda ALS items 0.1
# Confidence ALS 1
# Epochs 21
# [Epoch 0] : train RMSE = 1.9278
# [Epoch 0] : validation RMSE = 2.3866
# [Epoch 1] : train RMSE = 0.8301
# [Epoch 2] : train RMSE = 0.7815
# [Epoch 3] : train RMSE = 0.7645
# [Epoch 4] : train RMSE = 0.7558
# [Epoch 5] : train RMSE = 0.7504
# [Epoch 5] : validation RMSE = 1.0312
# [Epoch 6] : train RMSE = 0.7467
# [Epoch 7] : train RMSE = 0.7440
# [Epoch 8] : train RMSE = 0.7420
# [Epoch 9] : train RMSE = 0.7403
# [Epoch 10] : train RMSE = 0.7390
# [Epoch 10] : validation RMSE = 1.0462
# [Epoch 11] : train RMSE = 0.7379
# [Epoch 12] : train RMSE = 0.7370
# [Epoch 13] : train RMSE = 0.7362
# [Epoch 14] : train RMSE = 0.7355
# [Epoch 15] : train RMSE = 0.7349
# [Epoch 15] : validation RMSE = 1.0577
# [Epoch 16] : train RMSE = 0.7343
# [Epoch 17] : train RMSE = 0.7338
# [Epoch 18] : train RMSE = 0.7334
# [Epoch 19] : train RMSE = 0.7330
# [Epoch 20] : train RMSE = 0.7326
# [Epoch 20] : validation RMSE = 1.0672

# %%
train_rmse = [t for e, t, v in model.scbd]
test_rmse = [v for e, t, v in model.scbd]
epochs = [e for e, t, v in model.scbd]
plt.figure(figsize=((16,4)))
plt.plot(epochs, train_rmse, label="Train")
plt.plot(epochs, test_rmse, label="Test")
plt.legend()
plt.xticks(epochs, fontsize=8)
plt.xlabel("Epochs")
plt.ylabel("RMSE")
plt.grid(axis="y")

# %%
# 2
import math
lambda_l = [0.1, 1.0, 10.0, 100.0, 1000.0]
log_lambda_l = [math.log(k) for k in lambda_l]
min_test_rmse = []
for l in lambda_l:
    model = MFModel(X_train, X_test, users, items, hidden_dim=20, lr=0.01, gamma=l, reg_u=0.1, reg_i=0.1, epochs=10, optimizer='sgd')
    print("Starting training SGD with lambda = %r ..." % (l))
    model.print_hyper_params()
    model.train_model()
    test_rmse = sorted(model.scbd, key=lambda x: x[2])
    min_test_rmse.append(min(test_rmse))
# Out:
# Starting training SGD with lambda = 0.1 ...
# latent dimention 20
# learning rate 0.01
# lambda SGD 0.1
# lambda ALS users 0.1
# lambda ALS items 0.1
# Confidence ALS 1
# Epochs 10
# [Epoch 0] : train RMSE = 1.0485
# [Epoch 0] : validation RMSE = 1.0978
# [Epoch 1] : train RMSE = 0.9747
# [Epoch 2] : train RMSE = 0.9483
# [Epoch 3] : train RMSE = 0.9366
# [Epoch 4] : train RMSE = 0.9288
# [Epoch 5] : train RMSE = 0.9227
# [Epoch 5] : validation RMSE = 0.9432
# [Epoch 6] : train RMSE = 0.9145
# [Epoch 7] : train RMSE = 0.9051
# [Epoch 8] : train RMSE = 0.8975
# [Epoch 9] : train RMSE = 0.8910
# Starting training SGD with lambda = 1.0 ...
# latent dimention 20
# learning rate 0.01
# lambda SGD 1.0
# lambda ALS users 0.1
# lambda ALS items 0.1
# Confidence ALS 1
# Epochs 10
# [Epoch 0] : train RMSE = 1.6217
# [Epoch 0] : validation RMSE = 1.5736
# [Epoch 1] : train RMSE = 1.5688
# [Epoch 2] : train RMSE = 1.5529
# [Epoch 3] : train RMSE = 1.5459
# [Epoch 4] : train RMSE = 1.5345
# [Epoch 5] : train RMSE = 1.5228
# [Epoch 5] : validation RMSE = 1.4556
# [Epoch 6] : train RMSE = 1.4938
# [Epoch 7] : train RMSE = 1.4520
# [Epoch 8] : train RMSE = 1.4123
# [Epoch 9] : train RMSE = 1.3907
# Starting training SGD with lambda = 10.0 ...
# latent dimention 20
# learning rate 0.01
# lambda SGD 10.0
# lambda ALS users 0.1
# lambda ALS items 0.1
# Confidence ALS 1
# Epochs 10
# [Epoch 0] : train RMSE = 3.2010
# [Epoch 0] : validation RMSE = 3.0572
# [Epoch 1] : train RMSE = 3.2005
# [Epoch 2] : train RMSE = 3.2003
# [Epoch 3] : train RMSE = 3.1996
# [Epoch 4] : train RMSE = 3.1985
# [Epoch 5] : train RMSE = 3.1999
# [Epoch 5] : validation RMSE = 3.0554
# [Epoch 6] : train RMSE = 3.1997
# [Epoch 7] : train RMSE = 3.2006
# [Epoch 8] : train RMSE = 3.1991
# [Epoch 9] : train RMSE = 3.2003
# Starting training SGD with lambda = 100.0 ...
# latent dimention 20
# learning rate 0.01
# lambda SGD 100.0
# lambda ALS users 0.1
# lambda ALS items 0.1
# Confidence ALS 1
# Epochs 10
# [Epoch 0] : train RMSE = 3.7139
# [Epoch 0] : validation RMSE = 3.5561
# [Epoch 1] : train RMSE = 3.7145
# [Epoch 2] : train RMSE = 3.7146
# [Epoch 3] : train RMSE = 3.7151
# [Epoch 4] : train RMSE = 3.7146
# [Epoch 5] : train RMSE = 3.7143
# [Epoch 5] : validation RMSE = 3.5564
# [Epoch 6] : train RMSE = 3.7146
# [Epoch 7] : train RMSE = 3.7139
# [Epoch 8] : train RMSE = 3.7148
# [Epoch 9] : train RMSE = 3.7145
# Starting training SGD with lambda = 1000.0 ...
# latent dimention 20
# learning rate 0.01
# lambda SGD 1000.0
# lambda ALS users 0.1
# lambda ALS items 0.1
# Confidence ALS 1
# Epochs 10
# /Users/berryweinstein/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:105: RuntimeWarning: overflow encountered in multiply
# /Users/berryweinstein/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:104: RuntimeWarning: overflow encountered in multiply
# /Users/berryweinstein/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:105: RuntimeWarning: invalid value encountered in subtract
# [Epoch 0] : train RMSE = nan
# [Epoch 0] : validation RMSE = nan
# [Epoch 1] : train RMSE = nan
# [Epoch 2] : train RMSE = nan
# [Epoch 3] : train RMSE = nan
# [Epoch 4] : train RMSE = nan
# [Epoch 5] : train RMSE = nan
# [Epoch 5] : validation RMSE = nan
# [Epoch 6] : train RMSE = nan
# [Epoch 7] : train RMSE = nan
# [Epoch 8] : train RMSE = nan
# [Epoch 9] : train RMSE = nan

# %%
plt.figure(figsize=((16,4)))
plt.plot(log_lambda_l, [i[2] for i in min_test_rmse])
plt.xticks(log_lambda_l, fontsize=8)
plt.xlabel("Log lambda")
plt.ylabel("SGD RMSE")
plt.grid(axis="y")

# %%
# 3 + 4
import time
best_lambda = 0.1
k_l = [2, 4, 10, 20, 40, 50, 70, 100, 200]
time_meas = []
min_test_rmse = []
for k in k_l:
    model = MFModel(X_train, X_test, users, items, hidden_dim=k, lr=0.01, gamma=best_lambda, reg_u=0.1, reg_i=0.1, epochs=10, optimizer='sgd')
    print("Starting training SGD with K (hidden) = %d ..." % (k))
    model.print_hyper_params()
    start = time.time()
    model.train_model()
    end = time.time()
    time_meas.append(end - start)
    test_rmse = sorted(model.scbd, key=lambda x: x[2])
    min_test_rmse.append(min(test_rmse))
# Out:
# Starting training SGD with K (hidden) = 2 ...
# latent dimention 2
# learning rate 0.01
# lambda SGD 0.1
# lambda ALS users 0.1
# lambda ALS items 0.1
# Confidence ALS 1
# Epochs 10
# [Epoch 0] : train RMSE = 1.0500
# [Epoch 0] : validation RMSE = 1.1032
# [Epoch 1] : train RMSE = 0.9735
# [Epoch 2] : train RMSE = 0.9473
# [Epoch 3] : train RMSE = 0.9351
# [Epoch 4] : train RMSE = 0.9271
# [Epoch 5] : train RMSE = 0.9217
# [Epoch 5] : validation RMSE = 0.9447
# [Epoch 6] : train RMSE = 0.9181
# [Epoch 7] : train RMSE = 0.9128
# [Epoch 8] : train RMSE = 0.9087
# [Epoch 9] : train RMSE = 0.9043
# Starting training SGD with K (hidden) = 4 ...
# latent dimention 4
# learning rate 0.01
# lambda SGD 0.1
# lambda ALS users 0.1
# lambda ALS items 0.1
# Confidence ALS 1
# Epochs 10
# [Epoch 0] : train RMSE = 1.0473
# [Epoch 0] : validation RMSE = 1.0981
# [Epoch 1] : train RMSE = 0.9725
# [Epoch 2] : train RMSE = 0.9469
# [Epoch 3] : train RMSE = 0.9342
# [Epoch 4] : train RMSE = 0.9263
# [Epoch 5] : train RMSE = 0.9181
# [Epoch 5] : validation RMSE = 0.9416
# [Epoch 6] : train RMSE = 0.9106
# [Epoch 7] : train RMSE = 0.9021
# [Epoch 8] : train RMSE = 0.8928
# [Epoch 9] : train RMSE = 0.8869
# Starting training SGD with K (hidden) = 10 ...
# latent dimention 10
# learning rate 0.01
# lambda SGD 0.1
# lambda ALS users 0.1
# lambda ALS items 0.1
# Confidence ALS 1
# Epochs 10
# [Epoch 0] : train RMSE = 1.0480
# [Epoch 0] : validation RMSE = 1.0973
# [Epoch 1] : train RMSE = 0.9733
# [Epoch 2] : train RMSE = 0.9482
# [Epoch 3] : train RMSE = 0.9365
# [Epoch 4] : train RMSE = 0.9289
# [Epoch 5] : train RMSE = 0.9219
# [Epoch 5] : validation RMSE = 0.9434
# [Epoch 6] : train RMSE = 0.9137
# [Epoch 7] : train RMSE = 0.9056
# [Epoch 8] : train RMSE = 0.8967
# [Epoch 9] : train RMSE = 0.8894
# Starting training SGD with K (hidden) = 20 ...
# latent dimention 20
# learning rate 0.01
# lambda SGD 0.1
# lambda ALS users 0.1
# lambda ALS items 0.1
# Confidence ALS 1
# Epochs 10
# [Epoch 0] : train RMSE = 1.0483
# [Epoch 0] : validation RMSE = 1.0968
# [Epoch 1] : train RMSE = 0.9744
# [Epoch 2] : train RMSE = 0.9484
# [Epoch 3] : train RMSE = 0.9367
# [Epoch 4] : train RMSE = 0.9294
# [Epoch 5] : train RMSE = 0.9233
# [Epoch 5] : validation RMSE = 0.9429
# [Epoch 6] : train RMSE = 0.9152
# [Epoch 7] : train RMSE = 0.9080
# [Epoch 8] : train RMSE = 0.9004
# [Epoch 9] : train RMSE = 0.8937
# Starting training SGD with K (hidden) = 40 ...
# latent dimention 40
# learning rate 0.01
# lambda SGD 0.1
# lambda ALS users 0.1
# lambda ALS items 0.1
# Confidence ALS 1
# Epochs 10
# [Epoch 0] : train RMSE = 1.0495
# [Epoch 0] : validation RMSE = 1.0978
# [Epoch 1] : train RMSE = 0.9744
# [Epoch 2] : train RMSE = 0.9489
# [Epoch 3] : train RMSE = 0.9374
# [Epoch 4] : train RMSE = 0.9299
# [Epoch 5] : train RMSE = 0.9237
# [Epoch 5] : validation RMSE = 0.9433
# [Epoch 6] : train RMSE = 0.9177
# [Epoch 7] : train RMSE = 0.9111
# [Epoch 8] : train RMSE = 0.9033
# [Epoch 9] : train RMSE = 0.8952
# Starting training SGD with K (hidden) = 50 ...
# latent dimention 50
# learning rate 0.01
# lambda SGD 0.1
# lambda ALS users 0.1
# lambda ALS items 0.1
# Confidence ALS 1
# Epochs 10
# [Epoch 0] : train RMSE = 1.0490
# [Epoch 0] : validation RMSE = 1.0977
# [Epoch 1] : train RMSE = 0.9751
# [Epoch 2] : train RMSE = 0.9499
# [Epoch 3] : train RMSE = 0.9383
# [Epoch 4] : train RMSE = 0.9302
# [Epoch 5] : train RMSE = 0.9257
# [Epoch 5] : validation RMSE = 0.9444
# [Epoch 6] : train RMSE = 0.9198
# [Epoch 7] : train RMSE = 0.9128
# [Epoch 8] : train RMSE = 0.9046
# [Epoch 9] : train RMSE = 0.8979
# Starting training SGD with K (hidden) = 70 ...
# latent dimention 70
# learning rate 0.01
# lambda SGD 0.1
# lambda ALS users 0.1
# lambda ALS items 0.1
# Confidence ALS 1
# Epochs 10
# [Epoch 0] : train RMSE = 1.0499
# [Epoch 0] : validation RMSE = 1.0978
# [Epoch 1] : train RMSE = 0.9738
# [Epoch 2] : train RMSE = 0.9497
# [Epoch 3] : train RMSE = 0.9376
# [Epoch 4] : train RMSE = 0.9310
# [Epoch 5] : train RMSE = 0.9248
# [Epoch 5] : validation RMSE = 0.9445
# [Epoch 6] : train RMSE = 0.9200
# [Epoch 7] : train RMSE = 0.9133
# [Epoch 8] : train RMSE = 0.9059
# [Epoch 9] : train RMSE = 0.8979
# Starting training SGD with K (hidden) = 100 ...
# latent dimention 100
# learning rate 0.01
# lambda SGD 0.1
# lambda ALS users 0.1
# lambda ALS items 0.1
# Confidence ALS 1
# Epochs 10
# [Epoch 0] : train RMSE = 1.0484
# [Epoch 0] : validation RMSE = 1.0965
# [Epoch 1] : train RMSE = 0.9742
# [Epoch 2] : train RMSE = 0.9491
# [Epoch 3] : train RMSE = 0.9382
# [Epoch 4] : train RMSE = 0.9304
# [Epoch 5] : train RMSE = 0.9263
# [Epoch 5] : validation RMSE = 0.9455
# [Epoch 6] : train RMSE = 0.9213
# [Epoch 7] : train RMSE = 0.9167
# [Epoch 8] : train RMSE = 0.9091
# [Epoch 9] : train RMSE = 0.9021
# Starting training SGD with K (hidden) = 200 ...
# latent dimention 200
# learning rate 0.01
# lambda SGD 0.1
# lambda ALS users 0.1
# lambda ALS items 0.1
# Confidence ALS 1
# Epochs 10
# [Epoch 0] : train RMSE = 1.0488
# [Epoch 0] : validation RMSE = 1.0974
# [Epoch 1] : train RMSE = 0.9752
# [Epoch 2] : train RMSE = 0.9504
# [Epoch 3] : train RMSE = 0.9386
# [Epoch 4] : train RMSE = 0.9312
# [Epoch 5] : train RMSE = 0.9272
# [Epoch 5] : validation RMSE = 0.9450
# [Epoch 6] : train RMSE = 0.9228
# [Epoch 7] : train RMSE = 0.9198
# [Epoch 8] : train RMSE = 0.9145
# [Epoch 9] : train RMSE = 0.9068

# %%
plt.figure(figsize=((16,4)))
plt.plot(k_l, [i[2] for i in min_test_rmse])
plt.xticks(k_l, fontsize=8)
plt.xlabel("Latent dimention")
plt.ylabel("SGD RMSE")
plt.grid(axis="y")

# %%
plt.figure(figsize=((16,4)))
plt.plot(k_l, time_meas)
plt.xticks(k_l, fontsize=8)
plt.xlabel("Latent dimention")
plt.ylabel("Time in sec")
plt.grid(axis="y")
